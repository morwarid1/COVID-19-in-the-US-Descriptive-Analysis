# %%
# importing you libraries and data
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
import statsmodels.api as sm
import os
import warnings
warnings.filterwarnings ("ignore")
plt.style.use('fivethirtyeight')
import sklearn
from sklearn.cluster import KMeans
import pylab as pl
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# importing path
path = r'/Users/monajafizada/Documents/DataAnalytics/A6 advanced analytics and dashboard design/Project Information'

# %%
# Importing the data
dfM = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'ccdcmerged.csv'), index_col = False)

# %%
dfM.head(100)
# Out:
#     Unnamed: 0  State_x  Confirmed  Deaths
# 0            0  Alabama       1715      25
# 1            1  Alabama       5141      49
# 2            2  Alabama        851       7
# 3            3  Alabama        638      10
# 4            4  Alabama       1580      15
# ..         ...      ...        ...     ...
# 95          95   Alaska         17       0
# 96          96   Alaska         76       0
# 97          97   Alaska         13       0
# 98          98   Alaska         23       0
# 99          99   Alaska         79       1
#
# [100 rows x 4 columns]

# %%
dfM.shape
# Out:
# (3340, 4)

# %%
plt.style.use('seaborn-whitegrid')

# %%
# selecting only the necessary columns
dfM = dfM[["Confirmed","Deaths"]]

# %% [markdown]
# ### Data prep for regression analysis

# %%
# Ploting the data again with appropriate names
dfM.plot(x = 'Confirmed', y='Deaths',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('Covid-19 Deaths by confirmed cases')  
plt.xlabel('Confirmed')  
plt.ylabel('Deaths')  
plt.show()

# %%
# reshaping the values 
X = dfM['Confirmed'].values.reshape(-1,1)
y = dfM['Deaths'].values.reshape(-1,1)

# %%
X
# Out:
# array([[1715],
#        [5141],
#        [ 851],
#        ...,
#        [   0],
#        [ 113],
#        [  25]])

# %%
y
# Out:
# array([[25],
#        [49],
#        [ 7],
#        ...,
#        [ 0],
#        [ 6],
#        [ 0]])

# %%
# Split data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, random_state =0)

# %% [markdown]
# ### Regression analysis

# %%
# setting up for the regression analysis
regression = LinearRegression ()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted = regression.predict(X_test)

# %%
# plot the clusters 
plot_test = plt
plot_test.scatter(X_test, y_test, color='gray', s = 15)
plot_test.plot(X_test, y_predicted, color='red', linewidth =3)
plot_test.title('Covid 19 deaths cases by confirmed cases')
plot_test.xlabel('Confirmed')
plot_test.ylabel('Deaths')
plot_test.show()

# %% [markdown]
# ### Regression Analysis

# %%
# Create a scatterplot using matplotlib 
dfM.plot(x='Confirmed', y='Deaths')
plt.title('Confirmed cases over Deaths')
plt.xlabel('Confirmed Cases')
plt.ylabel('Death cases')
plt.show()

# %% [markdown]
# ### The elbow Technigue

# %%
num_cl = range(1,10)
kmeans = [KMeans(n_clusters =i) for i in num_cl]

# %%
score = [kmeans[i].fit(dfM).score(dfM) for i in range (len(kmeans))]
score
# Out:
# [-251187231901.11374,
#  -109476286692.56842,
#  -45507830052.85966,
#  -26503508068.24142,
#  -15667914545.071232,
#  -9071130052.923042,
#  -6587778268.433038,
#  -4687155802.872172,
#  -3395102920.698454]

# %%
pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# ### Clustering Analysis

# %%
# Create the K-means object 
kmeans = KMeans(n_clusters = 3, n_jobs = -1)

# %%
#Fit the k _mean object to the data
kmeans.fit(dfM)
# Out:
# KMeans(n_clusters=3, n_jobs=-1)

# %%
dfM['clusters']= kmeans.fit_predict(dfM)

# %%
dfM = dfM.reset_index()

# %%
dfM['clusters'].value_counts()
# Out:
# 1    3243
# 0      92
# 2       5
# Name: clusters, dtype: int64

# %%
dfM.dtypes
# Out:
# index        int64
# Confirmed    int64
# Deaths       int64
# clusters     int32
# dtype: object

# %%
# plot the clusters 
plt.figure(figsize=(12,8))
ax =sns.scatterplot(x=dfM ['Confirmed'],y=dfM['Deaths'],hue =kmeans.labels_, s=100)
plt.xlabel('Confirmed')
plt.ylabel('Deaths')
plt.title('Covid-19 Confirmed Cases and Deaths Cases')
plt.show()

# %%
dfM.head()
# Out:
#    index  Confirmed  Deaths  clusters
# 0      0       1715      25         1
# 1      1       5141      49         1
# 2      2        851       7         1
# 3      3        638      10         1
# 4      4       1580      15         1

# %%
# exporting the data
dfM.to_csv(os.path.join(path,'02 Data','PreparedData','cluster.csv'))

# %%
dfM.loc[dfM['clusters'] == 2, 'cluster'] = 'dark purple'
dfM.loc[dfM['clusters'] == 1, 'cluster'] = 'purple'
dfM.loc[dfM['clusters'] == 0, 'cluster'] = 'pink'

# %%
dfC = dfM.groupby('cluster').agg({'Confirmed':['mean', 'median'], 
                         'Deaths':['mean', 'median']})

# %%
dfC.head()
# Out:
#                  Confirmed                 Deaths
#                       mean    median         mean  median
# cluster
# dark purple   27809.195652   21675.5   995.760870   613.5
# pink           1086.598828     340.0    27.661116     5.0
# purple       170252.400000  140623.0  4113.800000  3304.0

# %%
# exporting the data
dfM.to_csv(os.path.join(path,'02 Data','PreparedData','DCMMcluster.csv'))
