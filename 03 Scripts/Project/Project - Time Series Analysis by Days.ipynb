# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
import os

# %%
path = r'/Users/monajafizada/Documents/DataAnalytics/A6 advanced analytics and dashboard design/Project Information'

# %%
dfM = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'Deaths-confirmed-Date.csv'), index_col = False)

# %%
# diplay all the rows from data frame
pd.set_option('display.max_rows',None)

# %%
dfM.head(1000)
# Out:
#            Date  Confirmed  Deaths
# 0    2020-01-22          0       0
# 1    2020-01-22          0       0
# 2    2020-01-22          0       0
# 3    2020-01-22          0       0
# 4    2020-01-22          0       0
# 5    2020-01-22          0       0
# 6    2020-01-22          0       0
# 7    2020-01-22          0       0
# 8    2020-01-22          0       0
# 9    2020-01-22          0       0
# 10   2020-01-22          0       0
# 11   2020-01-22          0       0
# 12   2020-01-22          0       0
# 13   2020-01-22          0       0
# 14   2020-01-22          0       0
# 15   2020-01-22          0       0
# 16   2020-01-22          0       0
# 17   2020-01-22          0       0
# 18   2020-01-22          0       0
# 19   2020-01-22          0       0
# 20   2020-01-22          0       0
# 21   2020-01-22          0       0
# 22   2020-01-22          0       0
# 23   2020-01-22          0       0
# 24   2020-01-22          0       0
# 25   2020-01-22          0       0
# ...

# %%
dfC = dfM[['Confirmed','Date']]
dfC.head()
# Out:
#    Confirmed        Date
# 0          0  2020-01-22
# 1          0  2020-01-22
# 2          0  2020-01-22
# 3          0  2020-01-22
# 4          0  2020-01-22

# %%
dfD = dfM[['Deaths','Date']]
dfD.head()
# Out:
#    Deaths        Date
# 0       0  2020-01-22
# 1       0  2020-01-22
# 2       0  2020-01-22
# 3       0  2020-01-22
# 4       0  2020-01-22

# %%
dfC = dfC.set_index('Date')
dfC.head()
# Out:
#             Confirmed
# Date
# 2020-01-22          0
# 2020-01-22          0
# 2020-01-22          0
# 2020-01-22          0
# 2020-01-22          0

# %%
dfD = dfD.set_index('Date')
dfD.head()
# Out:
#             Deaths
# Date
# 2020-01-22       0
# 2020-01-22       0
# 2020-01-22       0
# 2020-01-22       0
# 2020-01-22       0

# %%
dfC.shape
# Out:
# (821640, 1)

# %%
dfD.shape
# Out:
# (821640, 1)

# %%
dfC = dfC.reset_index()
dfC.head()
# Out:
#          Date  Confirmed
# 0  2020-01-22          0
# 1  2020-01-22          0
# 2  2020-01-22          0
# 3  2020-01-22          0
# 4  2020-01-22          0

# %%
dfD = dfD.reset_index()
dfD.head()
# Out:
#          Date  Deaths
# 0  2020-01-22       0
# 1  2020-01-22       0
# 2  2020-01-22       0
# 3  2020-01-22       0
# 4  2020-01-22       0

# %%
import datetime

# %%
dfC['DATE'] = pd.DatetimeIndex(dfC['Date']).month
dfC.head()
# Out:
#          Date  Confirmed  DATE
# 0  2020-01-22          0     1
# 1  2020-01-22          0     1
# 2  2020-01-22          0     1
# 3  2020-01-22          0     1
# 4  2020-01-22          0     1

# %%
dfD['DATE'] = pd.DatetimeIndex(dfD['Date']).month
dfD.head()
# Out:
#          Date  Deaths  DATE
# 0  2020-01-22       0     1
# 1  2020-01-22       0     1
# 2  2020-01-22       0     1
# 3  2020-01-22       0     1
# 4  2020-01-22       0     1

# %%
dfC =dfC[['Confirmed','DATE']]
dfC.head()
# Out:
#    Confirmed  DATE
# 0          0     1
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1

# %%
dfD =dfD[['Deaths','DATE']]
dfD.head()
# Out:
#    Deaths  DATE
# 0       0     1
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1

# %%
dfD.shape
# Out:
# (821640, 2)

# %%
# Time series of Confirmed caes of Covid 19
plt.figure(figsize=(20,5),dpi =100)
plt.plot(dfC)

# %%
# Time series of Deaths caes of Covid 19
plt.figure(figsize=(20,5),dpi =100)
plt.plot(dfD)

# %%
# mergering dfD and dfC on Date
DFM = pd.merge(dfC,dfD, on=["DATE"])

# %%
DFM.head(9)
# Out:
#       Confirmed   Deaths
# DATE
# 1            41        0
# 2           402        1
# 3       1117657    25324
# 4      19691985  1057534
# 5      45413492  2788799
# 6      64816883  3572191
# 7     111045108  4327115
# 8     166134262  5264077
# 9     149311209  4449203

# %%
# exporting the melted data
dfM.to_csv(os.path.join(path,'02 Data','PreparedData','Deaths_confirmed-Date-Sumed.csv'))
