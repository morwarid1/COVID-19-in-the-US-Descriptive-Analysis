# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Creating path 
path = r'/Users/monajafizada/Documents/DataAnalytics/A6 advanced analytics and dashboard design/Project Information'

# %% [markdown]
# Data 1

# %%
# importing Covid data of deaths by sex, age and states
Covid_Deaths_by_sex_age_States = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'COVID-19_Death_Counts_by_Sex__Age__and_State.csv'), index_col = False)

# %%
matplotlib.__version__
# Out:
# '3.3.3'

# %% [markdown]
# ### Cleaning

# %%
Covid_Deaths_by_sex_age_States.head()
# Out:
#    Unnamed: 0  Data as of  Start week    End Week          State  Sex  \
# 0           0  08/12/2020  02/01/2020  08/08/2020  United States  All
# 1           1  08/12/2020  02/01/2020  08/08/2020  United States  All
# 2           2  08/12/2020  02/01/2020  08/08/2020  United States  All
# 3           3  08/12/2020  02/01/2020  08/08/2020  United States  All
# 4           4  08/12/2020  02/01/2020  08/08/2020  United States  All
#
#       Age group  COVID-19 Deaths
# 0  Under 1 year             16.0
# 1     1-4 years             10.0
# 2    5-14 years             23.0
# 3   15-24 years            242.0
# 4   25-34 years           1133.0

# %%
# rename the column 
Covid_Deaths_by_sex_age_States = Covid_Deaths_by_sex_age_States.rename(columns={'Unnamed: 0':'No'})

# %%
Covid_Deaths_by_sex_age_States.dtypes
# Out:
# No                   int64
# Data as of          object
# Start week          object
# End Week            object
# State               object
# Sex                 object
# Age group           object
# COVID-19 Deaths    float64
# dtype: object

# %%
Covid_Deaths_by_sex_age_States.isnull().sum()
# Out:
# No                 0
# Data as of         0
# Start week         0
# End Week           0
# State              0
# Sex                0
# Age group          0
# COVID-19 Deaths    0
# dtype: int64

# %%
# finding duplicates
df_dups = Covid_Deaths_by_sex_age_States[Covid_Deaths_by_sex_age_States.duplicated()]

# %%
#no duplicates found
df_dups.shape
# Out:
# (0, 8)

# %% [markdown]
# ### Mixed-Type Data:

# %%
for col in Covid_Deaths_by_sex_age_States.columns.tolist():
      weird = (Covid_Deaths_by_sex_age_States[[col]].applymap(type) != Covid_Deaths_by_sex_age_States[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (Covid_Deaths_by_sex_age_States[weird]) > 0:
        print (col)

# No mixed-type columns either!

# %% [markdown]
# ### Exploring Relationships

# %% [markdown]
# ### Correlations:

# %%
# Create a correlation matrix using pandas
Covid_Deaths_by_sex_age_States.corr()
# Out:
#                        No  COVID-19 Deaths
# No               1.000000        -0.129326
# COVID-19 Deaths -0.129326         1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(Covid_Deaths_by_sex_age_States.corr())
plt.show()

# %%
# Add labels, a legend and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Covid_Deaths_by_sex_age_States.corr(), fignum=f.number) # type of plot
plt.xticks(range(Covid_Deaths_by_sex_age_States.shape[1]), Covid_Deaths_by_sex_age_States.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Covid_Deaths_by_sex_age_States.shape[1]), Covid_Deaths_by_sex_age_States.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ### Create a correlation heatmap using seaborn:

# %%
Covid_Deaths_by_sex_age_States.columns
# Out:
# Index(['No', 'Data as of', 'Start week', 'End Week', 'State', 'Sex',
#        'Age group', 'COVID-19 Deaths'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns

sub = Covid_Deaths_by_sex_age_States[['State', 'Sex',
       'Age group', 'COVID-19 Deaths']]

# %%
sub
# Out:
#                   State      Sex          Age group  COVID-19 Deaths
# 0         United States      All       Under 1 year             16.0
# 1         United States      All          1-4 years             10.0
# 2         United States      All         5-14 years             23.0
# 3         United States      All        15-24 years            242.0
# 4         United States      All        25-34 years           1133.0
# ...                 ...      ...                ...              ...
# 1411        Puerto Rico   Female        75-84 years              0.0
# 1412        Puerto Rico   Female  85 years and over              0.0
# 1413        Puerto Rico   Female           All ages             11.0
# 1414        Puerto Rico  Unknown           All ages              0.0
# 1415  Puerto Rico Total      All           All ages             34.0
#
# [1416 rows x 4 columns]

# %%
# Create a subplot with matplotlib. what it does is create an empty output, but this is okay-it's just to show the subplots.

f,ax = plt.subplots(figsize = (10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax =ax)

# The  'annot' argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %% [markdown]
# ### Scatterplots

# %%
# Create a scatterplot for the "House age" and "price"

sns.lmplot(x ='COVID-19 Deaths', y = 'COVID-19 Deaths', data = Covid_Deaths_by_sex_age_States)

# %% [markdown]
# ### Pair Plots:

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub [['State', 'Sex','Age group', 'COVID-19 Deaths']]

# %%
# Create a pair plot

g = sns.pairplot(sub_2)

# %% [markdown]
# ### Categorical Plots:

# %% [markdown]
# #### Creating a categorical varibale that splots the "COVID-19 Deaths" columns into categories

# %%
# Use a histogram to visualize the ditribution of the variables. This way, you can determine 
# sensible categories for the price ranges. you dont want to end up with too few observations 
# in any one of the categories. 
sns.displot(Covid_Deaths_by_sex_age_States['Age group'], bins = 40)

# %% [markdown]
# # Data 2

# %%
# importing Covid data of USA by cities
Covid_USA_City = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'covid_19_usa_city.csv'), index_col = False)

# %%
# creating a correlation matrix using pandas 

Covid_USA_City.corr()
# Out:
#                      Unnamed: 0  Total Cases  New Cases  Total Deaths  \
# Unnamed: 0             1.000000     0.340047   0.082011      0.182626
# Total Cases            0.340047     1.000000   0.361996      0.764083
# New Cases              0.082011     0.361996   1.000000      0.179639
# Total Deaths           0.182626     0.764083   0.179639      1.000000
# Total Cases /1M pop    0.699726     0.588955   0.223804      0.485489
# Total Tests            0.405766     0.907988   0.246985      0.703353
#
#                      Total Cases /1M pop  Total Tests
# Unnamed: 0                      0.699726     0.405766
# Total Cases                     0.588955     0.907988
# New Cases                       0.223804     0.246985
# Total Deaths                    0.485489     0.703353
# Total Cases /1M pop             1.000000     0.506658
# Total Tests                     0.506658     1.000000

# %%
# rename column
Covid_USA_City = Covid_USA_City.rename(columns={'Unnamed: 0':'No'})

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(Covid_USA_City.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Covid_USA_City.corr(), fignum=f.number) # type of plot
plt.xticks(range(Covid_USA_City.shape[1]), Covid_USA_City.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Covid_USA_City.shape[1]), Covid_USA_City.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
Covid_USA_City.columns
# Out:
# Index(['No', 'City', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Active Cases', 'Total Cases /1M pop', 'Deaths /1M pop', 'Total Tests',
#        'Tests /1M pop', 'Date'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns

sub_2 = Covid_USA_City[['City', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
       'Active Cases', 'Total Cases /1M pop', 'Deaths /1M pop', 'Total Tests',
       'Tests /1M pop',]]

# %%
sub_2
# Out:
#                 City  Total Cases    New Cases  Total Deaths New Deaths  \
# 0          New York        188694  7550.000000        9385.0       758
# 1        New Jersey         61850  3699.000000        2350.0       167
# 2          Michigan         23993   597.950107        1392.0
# 3     Massachusetts         22860   597.950107         686.0
# 4      Pennsylvania         22833  1029.000000         507.0         6
# ...              ...          ...          ...           ...        ...
# 8365  New Hampshire          8266    33.000000         439.0
# 8366         Alaska          7824   103.000000          56.0
# 8367        Wyoming          5948   127.000000          50.0
# 8368          Maine          5391    54.000000         141.0
# 8369        Vermont          1752     3.000000          58.0
#
#      Active Cases  Total Cases /1M pop Deaths /1M pop  Total Tests  \
# 0          162220               9618.0          478.0     461601.0
# ...

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub_2.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

#The coefficient from 
#0.5 - 1 is    strong correlation
#0.3 - 0.5 is  moderate correlation
#0.1 - o.3 is  weak correlation
#0             no correlation

# %% [markdown]
# ### Scatterplots:

# %%
# Create a scatterplot for the "Total Cases" and "Total Deaths" columns in seaborn

sns.lmplot(x = 'Total Cases', y = 'Total Deaths', data = Covid_USA_City)

# %% [markdown]
# ### Pair Plots:

# %%
# Keep only the variables you want to use in the pair plot

sub_2_1 = sub_2[['City', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
       'Active Cases', 'Total Cases /1M pop', 'Deaths /1M pop', 'Total Tests',
       'Tests /1M pop',]]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2_1)

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# #### Creating a categorical variable that splits the "Total Deaths" column into categories

# %%
# Use a histogram to visualize the distribution of the variables. This way, you can determine sensible categories for the price ranges. You dont want to end up with too few observation in any of the categories. 

sns.distplot(Covid_USA_City['Total Deaths'], bins = 30)
# Out:
# /Users/monajafizada/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Deaths', ylabel='Density'>

# %%
Covid_USA_City.loc[Covid_USA_City['Total Deaths'] < 500, 'Deaths category'] = 'Low Deaths'

# %%
Covid_USA_City.loc[(Covid_USA_City['Total Deaths'] >= 500) & (Covid_USA_City['Total Deaths'] < 3000), 'Deaths category'] = 'Average Deaths'

# %%
Covid_USA_City.loc[Covid_USA_City['Total Deaths'] >= 3000 , 'Deaths category'] = 'High Deaths'

# %%
Covid_USA_City['Deaths category'].value_counts(dropna = False)
# Out:
# Low Deaths        3527
# Average Deaths    3009
# High Deaths       1834
# Name: Deaths category, dtype: int64

# %%
Covid_USA_City.columns
# Out:
# Index(['No', 'City', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Active Cases', 'Total Cases /1M pop', 'Deaths /1M pop', 'Total Tests',
#        'Tests /1M pop', 'Date', 'Deaths category'],
#       dtype='object')

# %%
sns.set_theme(style="ticks")

# %%
Covid_USA_City.head()
# Out:
#    No            City  Total Cases    New Cases  Total Deaths New Deaths  \
# 0   0       New York        188694  7550.000000        9385.0       758
# 1   1     New Jersey         61850  3699.000000        2350.0       167
# 2   2       Michigan         23993   597.950107        1392.0
# 3   3  Massachusetts         22860   597.950107         686.0
# 4   4   Pennsylvania         22833  1029.000000         507.0         6
#
#   Active Cases  Total Cases /1M pop Deaths /1M pop  Total Tests Tests /1M pop  \
# 0       162220               9618.0          478.0     461601.0        23,529
# 1        58818               6964.0          265.0     126735.0        14,269
# 2        22158               2410.0          140.0      76014.0         7,634
# 3        21445               3347.0          100.0     108776.0        15,926
# 4        21676               1785.0           40.0     124890.0         9,764
#
#          Date Deaths category
# 0  04-12-2020     High Deaths
# ...

# %%
Covid_USA_City.columns
# Out:
# Index(['No', 'City', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Active Cases', 'Total Cases /1M pop', 'Deaths /1M pop', 'Total Tests',
#        'Tests /1M pop', 'Date', 'Deaths category'],
#       dtype='object')

# %%
# Create a subset and removing no and date

sub_2_C = Covid_USA_City[['City', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
       'Active Cases', 'Total Cases /1M pop', 'Deaths /1M pop', 'Total Tests',
       'Tests /1M pop','Deaths category']]

# %%
Covid_USA_City.shape
# Out:
# (8370, 13)

# %%
sub_2_C_Filered = sub_2_C [11:1000]

# %%
sub_2_C_Filered
# Out:
#              City  Total Cases    New Cases  Total Deaths New Deaths  \
# 11   Connecticut         11510   597.950107         494.0
# 12    Washington         10448   597.950107         494.0
# 13      Maryland          8225   531.000000         235.0        29
# 14       Indiana          7928   493.000000         343.0        13
# 15      Colorado          6893   597.950107         274.0
# ..            ...          ...          ...           ...        ...
# 995    Louisiana         29140   429.000000        1993.0        23
# 996  Connecticut         28764   597.950107        2339.0
# 997      Georgia         28215   719.000000        1172.0         6
# 998     Maryland         24473  1001.000000        1251.0        59
# 999      Indiana         19295   665.000000        1229.0        54
#
#     Active Cases  Total Cases /1M pop Deaths /1M pop  Total Tests  \
# 11         10966               3214.0          138.0      39831.0
# ...

# %%
# Create a categorical plot in seaborn using the price categories created above

g = sns.catplot(x="Total Cases", y="Total Deaths", hue="Deaths category", data = sub_2_C_Filered)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-3b65a6998106> in <module>
# ----> 1 g = sns.catplot(x="Total Cases", y="Total Deaths", hue="Deaths category", data = sub_2_C_Filered)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3832
#    3833     # Draw the plot onto the facets
# ...

# %% [markdown]
# ### Data 3

# %%
# importing Covid data of all country
Covid_country = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'covid_country.csv'), index_col = False)

# %%
Covid_country.shape
# Out:
# (30766, 15)

# %%
Covid_country.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Total Cases', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'Active Cases', 'Serious/Critical',
#        'Total Cases/1M pop', 'Deaths /1M pop', 'Total Tests', 'Tests /1M pop',
#        'Continent', 'Date'],
#       dtype='object')

# %%
# Rename the column
Covid_country = Covid_country.rename(columns={'Unnamed: 0':'No'})

# %%
Covid_country.dtypes
# Out:
# No                      int64
# Country                object
# Total Cases             int64
# New Cases             float64
# Total Deaths           object
# New Deaths            float64
# Total Recovered       float64
# Active Cases          float64
# Serious/Critical      float64
# Total Cases/1M pop    float64
# Deaths /1M pop        float64
# Total Tests           float64
# Tests /1M pop         float64
# Continent              object
# Date                   object
# dtype: object

# %%
Covid_country.head()
# Out:
#    No  Country  Total Cases    New Cases Total Deaths   New Deaths  \
# 0   1      USA       508575  5699.000000       19833   1086.000000
# 1   2    Spain       161852  3579.000000       16353    272.000000
# 2   3    Italy       152271  4694.000000       19468    619.000000
# 3   4   France       124869  2072.050442       13197     93.290591
# 4   5  Germany       123826  1655.000000        2736     93.290591
#
#    Total Recovered  Active Cases  Serious/Critical  Total Cases/1M pop  \
# 0          28224.0      460518.0           10947.0              1536.0
# 1          59109.0       86390.0            7371.0              3462.0
# 2          32534.0      100269.0            3381.0              2518.0
# 3          24932.0       86740.0            7004.0              1913.0
# 4          53913.0       67177.0            4895.0              1478.0
#
#    Deaths /1M pop  Total Tests  Tests /1M pop      Continent        Date
# ...

# %%
# find duplicates
df_dups_C = Covid_country[Covid_country.duplicated()]

# %%
df_dups_C.shape
# Out:
# (0, 15)

# %%
for col in Covid_country.columns.tolist():
    weird = (Covid_country[[col]].applymap(type) != Covid_country[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (Covid_country[weird]) > 0:
        print (col)
        
        
# no mixed-type columns was found

# %% [markdown]
# #### Correlations

# %%
# Create a correlation matrix using pandas

Covid_country.corr()
# Out:
#                           No  Total Cases  New Cases  New Deaths  \
# No                  1.000000     0.117408   0.070066   -0.005096
# Total Cases         0.117408     1.000000   0.683588    0.464069
# New Cases           0.070066     0.683588   1.000000    0.656379
# New Deaths         -0.005096     0.464069   0.656379    1.000000
# Total Recovered     0.135357     0.972841   0.701787    0.454095
# Active Cases        0.058414     0.917744   0.570758    0.425164
# Serious/Critical    0.017856     0.762178   0.581283    0.539735
# Total Cases/1M pop  0.304657     0.256796   0.080413    0.011543
# Deaths /1M pop      0.151939     0.261786   0.094026    0.106691
# Total Tests         0.132788     0.773123   0.538852    0.323511
# Tests /1M pop       0.277355     0.041427  -0.000559   -0.001819
#
#                     Total Recovered  Active Cases  Serious/Critical  \
# No                         0.135357      0.058414          0.017856
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(Covid_country.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Covid_country.corr(), fignum=f.number) # type of plot
plt.xticks(range(Covid_country.shape[1]), Covid_country.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Covid_country.shape[1]), Covid_country.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
Covid_country.columns
# Out:
# Index(['No', 'Country', 'Total Cases', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'Active Cases', 'Serious/Critical',
#        'Total Cases/1M pop', 'Deaths /1M pop', 'Total Tests', 'Tests /1M pop',
#        'Continent', 'Date'],
#       dtype='object')

# %%
# Create a subset exluding the "Date" and "No" columns

sub_CC = Covid_country [['Country', 'Total Cases', 'New Cases', 'Total Deaths',
       'New Deaths', 'Total Recovered', 'Active Cases', 'Serious/Critical',
       'Total Cases/1M pop', 'Deaths /1M pop', 'Total Tests', 'Tests /1M pop',
       'Continent']]

# %%
sub_CC
# Out:
#                      Country  Total Cases    New Cases Total Deaths  \
# 0                        USA       508575  5699.000000       19833
# 1                      Spain       161852  3579.000000       16353
# 2                      Italy       152271  4694.000000       19468
# 3                     France       124869  2072.050442       13197
# 4                    Germany       123826  1655.000000        2736
# ...                      ...          ...          ...          ...
# 30761  Saint Kitts and Nevis           19  2072.050442
# 30762  Saint Pierre Miquelon           16  2072.050442
# 30763              Greenland           14  2072.050442
# 30764             Montserrat           13  2072.050442           1
# 30765       Falkland Islands           13  2072.050442
#
#         New Deaths  Total Recovered  Active Cases  Serious/Critical  \
# 0      1086.000000          28224.0      460518.0      10947.000000
# 1       272.000000          59109.0       86390.0       7371.000000
# ...

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is oky-its just to show the subplots.
f,ax = plt.subplots (figsize =(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr =sns.heatmap(sub_CC.corr(), annot = True, ax = ax)

# %%
corr.figure

# %% [markdown]
# ### Scatterplots:

# %%
# Create a scatterplot for the " Total test" and "New Deaths"

sns.lmplot(x = 'Total Tests', y = 'New Deaths', data = Covid_country)

# %% [markdown]
# ### Pair Plots:

# %%
sub_CC_2 = sub_CC [['Country','Total Tests', 'Total Cases', 'New Cases', 'Total Deaths',
       'New Deaths', 'Total Recovered', 'Active Cases', 'Serious/Critical']]

# %%
# Create a pair plot
g = sns.pairplot(sub_CC_2)

# %% [markdown]
# ### Categorical Plots:

# %%
Covid_country.columns
# Out:
# Index(['No', 'Country', 'Total Cases', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'Active Cases', 'Serious/Critical',
#        'Total Cases/1M pop', 'Deaths /1M pop', 'Total Tests', 'Tests /1M pop',
#        'Continent', 'Date'],
#       dtype='object')

# %%
# using a histogram to visualize the ditribution of the variables. 
# This way, you can determine sensible categories for the price ranges.
# You dont want to end up with too few observation in any one of the categories

sns.displot(Covid_country['Deaths /1M pop'], bins = 30)

# %% [markdown]
# ### Data 4

# %%
# importing general Covid data 
Covid_Data = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'C19_data.csv'), index_col = False)

# %%
Covid_Data.head()
# Out:
#    Unnamed: 0  SNo ObservationDate Province/State  Country/Region  \
# 0           0    1      01/22/2020          Anhui  Mainland China
# 1           1    2      01/22/2020        Beijing  Mainland China
# 2           2    3      01/22/2020      Chongqing  Mainland China
# 3           3    4      01/22/2020         Fujian  Mainland China
# 4           4    5      01/22/2020          Gansu  Mainland China
#
#        Last Update  Confirmed  Deaths  Recovered
# 0  1/22/2020 17:00          1       0          0
# 1  1/22/2020 17:00         14       0          0
# 2  1/22/2020 17:00          6       0          0
# 3  1/22/2020 17:00          1       0          0
# 4  1/22/2020 17:00          0       0          0

# %%
Covid_Data.shape
# Out:
# (81452, 9)

# %%
Covid_Data.columns
# Out:
# Index(['Unnamed: 0', 'SNo', 'ObservationDate', 'Province/State',
#        'Country/Region', 'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
# Rename the column
Covid_Data = Covid_Data.rename(columns={'Unnamed: 0':'No'})

# %%
Covid_Data.dtypes
# Out:
# No                  int64
# SNo                 int64
# ObservationDate    object
# Province/State     object
# Country/Region     object
# Last Update        object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# dtype: object

# %%
# Missing values
Covid_Data.isnull().sum()
# Out:
# No                 0
# SNo                0
# ObservationDate    0
# Province/State     0
# Country/Region     0
# Last Update        0
# Confirmed          0
# Deaths             0
# Recovered          0
# dtype: int64

# %%
# find duplicates
Covid_Data_dups = Covid_Data[Covid_Data.duplicated()]

# %%
Covid_Data_dups.shape
# Out:
# (0, 9)

# %%
# Checking for the mixed-type data
for col in Covid_Data.columns.tolist():
      weird = (Covid_Data[[col]].applymap(type) != Covid_Data[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (Covid_Data[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %% [markdown]
# ### Exploring Relationships

# %% [markdown]
# ### Correlations

# %%
Covid_Data.corr()
# Out:
#                  No       SNo  Confirmed    Deaths  Recovered
# No         1.000000  1.000000   0.185719  0.116260   0.111422
# SNo        1.000000  1.000000   0.185719  0.116260   0.111422
# Confirmed  0.185719  0.185719   1.000000  0.760064   0.334931
# Deaths     0.116260  0.116260   0.760064  1.000000   0.214623
# Recovered  0.111422  0.111422   0.334931  0.214623   1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(Covid_Data.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Covid_Data.corr(), fignum=f.number) # type of plot
plt.xticks(range(Covid_Data.shape[1]), Covid_Data.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Covid_Data.shape[1]), Covid_Data.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Create a correlation heatmap using seaborn
Covid_Data.columns
# Out:
# Index(['No', 'SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
# Create a subset excluding the "Data" and "No" columns

sub_Covid_Data = Covid_Data[['Province/State', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered']]

# %%
sub_Covid_Data
# Out:
#           Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0                  Anhui  Mainland China          1       0          0
# 1                Beijing  Mainland China         14       0          0
# 2              Chongqing  Mainland China          6       0          0
# 3                 Fujian  Mainland China          1       0          0
# 4                  Gansu  Mainland China          0       0          0
# ...                  ...             ...        ...     ...        ...
# 81447  Zaporizhia Oblast         Ukraine       3149      49       1158
# 81448            Zeeland     Netherlands       1270      72          0
# 81449           Zhejiang  Mainland China       1282       1       1272
# 81450    Zhytomyr Oblast         Ukraine       5191      92       2853
# 81451       Zuid-Holland     Netherlands      29513    1372          0
#
# [81452 rows x 5 columns]

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub_Covid_Data.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %% [markdown]
# ### Scatterplots

# %%
sns.lmplot(x = 'Deaths', y = 'Confirmed', data = Covid_Data )

# %% [markdown]
# ### Pair plots:

# %%
# Create a pair plot
g = sns.pairplot(sub_Covid_Data)

# %% [markdown]
# ### Categorical plots:

# %% [markdown]
# ### Data 5

# %%
# importing general Covid data of the world
Covid_open_line = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'C19_open_line_list.csv'), index_col = False)

# %%
Covid_open_line.shape
# Out:
# (13174, 34)

# %%
Covid_open_line.head()
# Out:
#    No   ID age     sex                        city province country  \
# 0   0  1.0  30    male     Chaohu City, Hefei City    Anhui   China
# 1   1  2.0  47    male  Baohe District, Hefei City    Anhui   China
# 2   2  3.0  49    male  High-Tech Zone, Hefei City    Anhui   China
# 3   3  4.0  47  female  High-Tech Zone, Hefei City    Anhui   China
# 4   4  5.0  50  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude  ... outcome  \
# 0                    1.0  31.646960  117.716600  ...     NaN
# 1                    1.0  31.778630  117.331900  ...     NaN
# 2                    1.0  31.828313  117.224844  ...     NaN
# 3                    1.0  31.828313  117.224844  ...     NaN
# 4                    1.0  32.001230  117.568100  ...     NaN
#
#   date_death_or_discharge notes_for_discussion        location  \
# 0                     NaN                  NaN             NaN
# ...

# %%
Covid_open_line.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')

# %%
# Rename the column
Covid_open_line = Covid_open_line.rename(columns={'Unnamed: 0':'No'})

# %%
# Find duplicates

Covid_open_line_dups = Covid_open_line[Covid_open_line.duplicated()]

# %%
Covid_open_line_dups.shape # No duplicatess!
# Out:
# (0, 34)

# %%
for col in Covid_open_line.columns.tolist():
      weird = (Covid_open_line[[col]].applymap(type) != Covid_open_line[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (Covid_open_line[weird]) > 0:
        print (col)
        
# No mixed-type columns either!
# Out:
# age
# sex
# city
# province
# country
# geo_resolution
# date_onset_symptoms
# date_admission_hospital
# date_confirmation
# symptoms
# lives_in_Wuhan
# travel_history_dates
# travel_history_location
# reported_market_exposure
# additional_information
# chronic_disease
# source
# sequence_available
# outcome
# date_death_or_discharge
# notes_for_discussion
# location
# admin3
# admin2
# admin1
# country_new
# admin_id
# data_moderator_initials

# %%
# Create a correlation matrix using pandas

Covid_open_line.corr()
# Out:
#                               No        ID  wuhan(0)_not_wuhan(1)  latitude  \
# No                      1.000000  0.999908                    NaN  0.254158
# ID                      0.999908  1.000000                    NaN  0.252450
# wuhan(0)_not_wuhan(1)        NaN       NaN                    NaN       NaN
# latitude                0.254158  0.252450                    NaN  1.000000
# longitude              -0.225731 -0.222762                    NaN -0.279366
# chronic_disease_binary  0.014198  0.014237                    NaN -0.036176
#
#                         longitude  chronic_disease_binary
# No                      -0.225731                0.014198
# ID                      -0.222762                0.014237
# wuhan(0)_not_wuhan(1)         NaN                     NaN
# latitude                -0.279366               -0.036176
# longitude                1.000000                0.027565
# chronic_disease_binary   0.027565                1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(Covid_open_line.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(Covid_open_line.corr(), fignum=f.number) # type of plot
plt.xticks(range(Covid_open_line.shape[1]), Covid_open_line.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(Covid_open_line.shape[1]), Covid_open_line.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
Covid_open_line.columns
# Out:
# Index(['No', 'ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns

sub = Covid_open_line[['age', 'sex', 'city', 'province', 'country', 'latitude', 'longitude', 'geo_resolution',
       'symptoms', 'lives_in_Wuhan', 'travel_history_dates','travel_history_location', 'reported_market_exposure',
       'additional_information', 'chronic_disease_binary', 'chronic_disease',
       'source', 'outcome', 'location', 'admin3', 'admin2', 'admin1',
       'country_new', 'admin_id', 'data_moderator_initials']]

# %%
sub
# Out:
#          age     sex                                       city  \
# 0         30    male                    Chaohu City, Hefei City
# 1         47    male                 Baohe District, Hefei City
# 2         49    male                 High-Tech Zone, Hefei City
# 3         47  female                 High-Tech Zone, Hefei City
# 4         50  female                 Feidong County, Hefei City
# ...      ...     ...                                        ...
# 13169  60-69    male                                Nagoya City
# 13170  40-49  female                                        NaN
# 13171   0-10  female                                        NaN
# 13172    NaN  female                                  Amsterdam
# 13173    NaN  female  Jose Joaquin de Olmedo Airport, Guayaquil
#
#                province      country   latitude   longitude geo_resolution  \
# 0                 Anhui        China  31.646960  117.716600         admin3
# ...

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %%
### Scatterplots

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'House age', y = 'Price per unit', data = Covid_open_line)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-d962af658a0b> in <module>
#       1 # Create a scatterplot for the "house age" and "price per unit" columns in seaborn
#       2
# ----> 3 sns.lmplot(x = 'House age', y = 'Price per unit', data = Covid_open_line)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['House age', 'D. metro', 'N. shops', 'Price per unit']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# ### Data 6

# %%
# importing Covid data of US confrimed cases
TS_US_Confirmed = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'TS_C19_confirmed_US.csv'), index_col = False)

# %%
TS_US_Confirmed.shape
# Out:
# (3340, 258)

# %%
TS_US_Confirmed.columns
# Out:
# Index(['Unnamed: 0', 'UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2',
#        'Province_State', 'Country_Region', 'Lat',
#        ...
#        '9/14/20', '9/15/20', '9/16/20', '9/17/20', '9/18/20', '9/19/20',
#        '9/20/20', '9/21/20', '9/22/20', '9/23/20'],
#       dtype='object', length=258)

# %%
# Rename the column
TS_US_Confirmed = TS_US_Confirmed.rename(columns={'Unnamed: 0':'No'})

# %%
# Check for missing values

TS_US_Confirmed.isnull().sum() # No missing values!
# Out:
# No         0
# UID        0
# iso2       0
# iso3       0
# code3      0
#           ..
# 9/19/20    0
# 9/20/20    0
# 9/21/20    0
# 9/22/20    0
# 9/23/20    0
# Length: 258, dtype: int64

# %%
# Find duplicates

TS_US_Confirmed_dups = TS_US_Confirmed[TS_US_Confirmed.duplicated()]

# %%
TS_US_Confirmed_dups.shape # No duplicatess!
# Out:
# (0, 258)

# %%
for col in TS_US_Confirmed.columns.tolist():
      weird = (TS_US_Confirmed[[col]].applymap(type) != TS_US_Confirmed[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (TS_US_Confirmed[weird]) > 0:
        print (col)
        
# No mixed-type columns either!
# Out:
# Admin2

# %%
# Create a correlation matrix using pandas

TS_US_Confirmed.corr()
# Out:
#                No       UID     code3      FIPS       Lat     Long_   1/22/20  \
# No       1.000000 -0.084080 -0.094772  0.800346  0.007390  0.062229  0.026735
# UID     -0.084080  1.000000  0.903836 -0.198912  0.314965 -0.235989  0.002501
# code3   -0.094772  0.903836  1.000000 -0.265912  0.341832 -0.195156  0.002612
# FIPS     0.800346 -0.198912 -0.265912  1.000000 -0.453129  0.483018  0.018574
# Lat      0.007390  0.314965  0.341832 -0.453129  1.000000 -0.721129  0.020596
# ...           ...       ...       ...       ...       ...       ...       ...
# 9/19/20 -0.068214  0.023679  0.026651 -0.079021 -0.024436 -0.023830  0.039462
# 9/20/20 -0.067942  0.023613  0.026570 -0.078787 -0.024469 -0.023916  0.039417
# 9/21/20 -0.066736  0.023475  0.026414 -0.077699 -0.024787 -0.023999  0.039119
# 9/22/20 -0.066453  0.023528  0.026483 -0.077570 -0.024773 -0.024198  0.039046
# 9/23/20 -0.066535  0.023586  0.026562 -0.077781 -0.024470 -0.024428  0.039087
#
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(TS_US_Confirmed.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(TS_US_Confirmed.corr(), fignum=f.number) # type of plot
plt.xticks(range(TS_US_Confirmed.shape[1]), TS_US_Confirmed.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(TS_US_Confirmed.shape[1]), TS_US_Confirmed.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
TS_US_Confirmed.columns

# %%
# Create a subset excluding the "Date" and "No" columns

sub = TS_US_Confirmed[['House age', 'D. metro', 'N. shops', 'Latitude','Longitude', 'Price per unit']]

# %%
sub

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'House age', y = 'Price per unit', data = TS_US_Confirmed)

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['House age', 'D. metro', 'N. shops', 'Price per unit']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# ### Data 7

# %%
# importing Covid data of Time series by confirmed cases
TS_Confirmed = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'TS_C19_confirmed.csv'), index_col = False)

# %%
df.shape

# %%
df.columns

# %%
# Rename the column
Covid_Data = Covid_Data.rename(columns={'Unnamed: 0':'No'})

# %%
# Check for missing values

df.isnull().sum() # No missing values!

# %%
# Find duplicates

df_dups = df[df.duplicated()]

# %%
df_dups.shape # No duplicatess!

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
# Create a correlation matrix using pandas

df.corr()

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title

# %%
df.columns

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[['House age', 'D. metro', 'N. shops', 'Latitude','Longitude', 'Price per unit']]

# %%
sub

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'House age', y = 'Price per unit', data = df)

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['House age', 'D. metro', 'N. shops', 'Price per unit']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# ### Data 8

# %%
# importing Covid data of Times series by US deaths
TS_US_deaths = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'TS_C19_deaths_US.csv'), index_col = False)

# %%
df.shape

# %%
df.columns

# %%
# Rename the column
Covid_Data = Covid_Data.rename(columns={'Unnamed: 0':'No'})

# %%
# Check for missing values

df.isnull().sum() # No missing values!

# %%
# Find duplicates

df_dups = df[df.duplicated()]

# %%
df_dups.shape # No duplicatess!

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
# Create a correlation matrix using pandas

df.corr()

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title

# %%
df.columns

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[['House age', 'D. metro', 'N. shops', 'Latitude','Longitude', 'Price per unit']]

# %%
sub

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'House age', y = 'Price per unit', data = df)

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['House age', 'D. metro', 'N. shops', 'Price per unit']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# ## Data 9

# %%
# importing Covid data of Time series by deaths
TS_deaths = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'TS_C19_deaths.csv'), index_col = False)

# %%
df.shape

# %%
df.columns

# %%
# Rename the column
Covid_Data = Covid_Data.rename(columns={'Unnamed: 0':'No'})

# %%
# Check for missing values

df.isnull().sum() # No missing values!

# %%
# Find duplicates

df_dups = df[df.duplicated()]

# %%
df_dups.shape # No duplicatess!

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
# Create a correlation matrix using pandas

df.corr()

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title

# %%
df.columns

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[['House age', 'D. metro', 'N. shops', 'Latitude','Longitude', 'Price per unit']]

# %%
sub

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'House age', y = 'Price per unit', data = df)

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['House age', 'D. metro', 'N. shops', 'Price per unit']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# ### Data 10

# %%
# importing Covid data of Time series by recovered cases
TS_recovered = pd.read_csv(os.path.join(path, '02 Data', 'PreparedData', 'TS_C19_recovered.csv'), index_col = False)

# %%
df.shape

# %%
df.columns

# %%
# Rename the column
Covid_Data = Covid_Data.rename(columns={'Unnamed: 0':'No'})

# %%
# Check for missing values

df.isnull().sum() # No missing values!

# %%
# Find duplicates

df_dups = df[df.duplicated()]

# %%
df_dups.shape # No duplicatess!

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
# Create a correlation matrix using pandas

df.corr()

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title

# %%
df.columns

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[['House age', 'D. metro', 'N. shops', 'Latitude','Longitude', 'Price per unit']]

# %%
sub

# %%
# Create a subplot with matplotlib. What it does is create an empty output, but this is okay—it's just to show the subplots.

f,ax = plt.subplots(figsize=(10,10))

# %%
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 

# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.

# %%
corr.figure

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'House age', y = 'Price per unit', data = df)

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['House age', 'D. metro', 'N. shops', 'Price per unit']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)
